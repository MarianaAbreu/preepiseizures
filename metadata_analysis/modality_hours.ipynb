# %%
import json

import pandas as pd

import eval_quality as eq

# %%
table_all = pd.DataFrame()

patient_dict = json.load(open('patient_info.json'))
_, _, _, chestbit_dur = eq.final_table(source='wearable', device='chestbit', sensor='ecg')
_, _, _, wristbit_dur = eq.final_table(source='wearable', device='wristbit', sensor='ppg')
_, _, _, armbit_dur = eq.final_table(source='wearable', device='armbit', sensor='ecg')

    else: 
        device = 'wristbit'
    _, _, _, ll = eq.final_table(source='wearable', device=device, sensor=sensor)
    new_row = pd.DataFrame({'total_duration': ll, 'device':device, 'sensor': sensor}, index=[0])
    table_all = pd.concat((table_all, new_row), ignore_index=True)
    # print(f'{sensor.upper()} \n {table_w} \n N patients: {wN} \n Total duration: {wdur}')
print('ok')
# Out:
# Patient VNVW has data completeness 2.2396843321125504
# Patient WOSQ has data completeness 1.4158062880685816
# Patient QFRK has data completeness 2.255067968539824
# Patient OQQA has data completeness 2.3885874490048784
# Patient LDXH has data completeness 2.3094990957064216
# Patient QFRK has data completeness 2.255067968539824
# Patient YWJN has data completeness 1.3455312820922463
# Patient WOSQ has data completeness 1.4158062880685816
# Patient OQQA has data completeness 2.3885874490048784
# Patient YWJN has data completeness 1.3455312820922463
# Patient RAFI has data completeness 1.6742637100349416
# Patient QFRK has data completeness 2.255067968539824
# Patient RMJL has data completeness 1.781184671405873
# Patient RMJL has data completeness 1.781184671405873
# Patient RMJL has data completeness 1.781184671405873
# Patient VNVW has data completeness 2.2396843321125504
# Patient RAFI has data completeness 1.6742637100349416
# ...

# %%
table_all
# Out:
#            total_duration    device sensor
# 0 92 days 03:53:29.426539  chestbit    ecg
# 1 93 days 06:56:52.337625  chestbit   pzt2
# 2 21 days 06:04:07.667000  wristbit    eda
# 3 21 days 06:01:43.393000  wristbit    bvp
